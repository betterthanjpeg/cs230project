# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
cd /content/drive/My\ Drive/School/Year6/CS230/Project/Coco\ Data
# Out:
# /content/drive/My Drive/School/Year6/CS230/Project/Coco Data

# %%
#!git clone https://github.com/anishathalye/neural-style.git

# %%
cd neural-style/
# Out:
# /content/drive/My Drive/School/Year6/CS230/Project/Coco Data/neural-style

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 31.2MB 1.5MB/s
# ...
#      |████████████████████████████████| 411.5MB 40kB/s
# ...
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# ...
#   Found existing installation: scipy 1.3.3
#     Uninstalling scipy-1.3.3:
#       Successfully uninstalled scipy-1.3.3
# ...

# %%
#download the pretrained model
#!wget http://www.vlfeat.org/matconvnet/models/imagenet-vgg-verydeep-19.mat

# %%
# download requirements for GAN --doesn't work with neural style transfer

#!pip install tensorflow-gpu==2.0.0-alpha0
#!git clone https://www.github.com/keras-team/keras-contrib.git \
#    && cd keras-contrib \
#    && python convert_to_tf_keras.py \
#    && USE_TF_KERAS=1 python setup.py install

# %%
## Initializations for COCO

# %matplotlib inline
from pycocotools.coco import COCO
import numpy as np
import skimage.io as io
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import pylab
pylab.rcParams['figure.figsize'] = (8.0, 10.0)
dataDir='..'
dataType='val2017'
annFile='{}/annotations/instances_{}.json'.format(dataDir,dataType)

# initialize COCO api for instance annotations
coco=COCO(annFile)

# get all images containing given categories
catIds = coco.getCatIds(catNms=['person','outdoor']);
imgIds = coco.getImgIds(catIds=catIds );
# Out:
# loading annotations into memory...
# Done (t=0.83s)
# creating index...
# index created!

# %%
ls
# Out:
#  examples/                        neural_style.py    README.md
#  imagenet-vgg-verydeep-19.mat     outtestimg_1.jpg   requirements.txt
#  imagenet-vgg-verydeep-19.mat.1   outtestimg_2.jpg   stylize.py
#  imagenet-vgg-verydeep-19.mat.2   outtestimg_3.jpg  'test images'/
#  imagenet-vgg-verydeep-19.mat.3   outtestimg_4.jpg  'test images.zip'
#  imagenet-vgg-verydeep-19.mat.4   outtestimg_5.jpg   vgg.py
#  LICENSE.txt                      __pycache__/

# %%
## Define parameters
import os

NUMIMGS = 2
DIRCOCO = '/content/drive/My Drive/School/Year6/CS230/Project/Coco Data/val2017'
DIRNEURAL = '/content/drive/My Drive/School/Year6/CS230/Project/neural-style'
DIROUT = '/content/drive/My Drive/School/Year6/CS230/Project/Imgs/neuraltest'
styleimg = '/content/drive/My Drive/School/Year6/CS230/Project/Imgs/coco.jpg'
stylepath = os.path.normpath(styleimg)

DIRGAN = '/content/drive/My\ Drive/School/Year6/CS230/Project/CartoonGan-tensorflow'


from shutil import copyfile

# %%
## Change neural_style.py code to allow for different paths
#cat neural-style/neural_style.py

# %%
pwd
# Out:
# '/content/drive/My Drive/School/Year6/CS230/Project/Coco Data/neural-style'

# %%
## Loop
#for i in range(8):
  # get image from COCO. select one at random
  
  #*os.chdir(DIRCOCO);
  #*idRand = np.random.randint(0,len(imgIds));
  #*img = coco.loadImgs(imgIds[idRand])[0];
  
  #contentimg = os.path.join(DIRCOCO,img['file_name'])
  #contentimg = DIRCOCO + '/' + img['file_name'];
  #print(contentimg)
  #print(img['file_name'])
  
  #contentpath = os.path.normpath(contentimg)
  #contentpath = os.path.normpath(img['file_name'])
  #print(os.path.exists(contentpath))

  
  # run through GAN later ---having a really hard time doing that with the same tensorflow version
  #*copyfile(img['file_name'],'/content/drive/My Drive/School/Year6/CS230/Project/Imgs/inputforup/'+ img['file_name'])
  
  #!python /content/drive/'My Drive'/School/Year6/CS230/Project/CartoonGan-tensorflow/cartoonize.py \
  #--styles paprika \
  #--batch_size 1 \
  #--comparison_view horizontal
  
  # run through neural style transfer
  #outputimg = DIROUT + 'outimg_' + str(i) +'.jpg'
  #outputpath = os.path.normpath(outputimg)
  #os.chdir(DIROUT);
  
  #!python neural_style.py --content contentimg --styles styleimg --output outputimg --style-layer-weight-exp 1.5 --preserve-colors
  # !python /content/drive/'My Drive'/School/Year6/CS230/Project/'Coco Data'/neural-style/neural_style.py \
  --content 20191208_122210_131.jpg \
  --styles /content/drive/'My Drive'/School/Year6/CS230/Project/Imgs/up.jpg \
  --output {'outtestimg_6.jpg'} \
  --style-layer-weight-exp 1.5 \
  --preserve-colors
# Out:
# WARNING:tensorflow:From /content/drive/My Drive/School/Year6/CS230/Project/Coco Data/neural-style/vgg.py:9: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/School/Year6/CS230/Project/Coco Data/neural-style/vgg.py:11: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2019-12-08 23:49:51.370920: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2019-12-08 23:49:51.376727: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2019-12-08 23:49:51.377028: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x26372c0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2019-12-08 23:49:51.377076: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# ...

# %%
# !python neural_style.py --content contentpath --styles stylepath --output outputpath --style-layer-weight-exp 1.5 --preserve-colors
# Out:
# WARNING:tensorflow:From /content/drive/My Drive/School/Year6/CS230/Project/neural-style/vgg.py:9: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/School/Year6/CS230/Project/neural-style/vgg.py:11: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2019-11-06 01:58:20.079603: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2019-11-06 01:58:20.084962: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2019-11-06 01:58:20.085213: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x23812c0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2019-11-06 01:58:20.085249: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# ...
